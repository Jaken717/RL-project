# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install "stable-baselines3[extra]" gymnasium[classic-control] --quiet

import math
import numpy as np
import gymnasium as gym
from gymnasium.envs.classic_control import CartPoleEnv
from gymnasium.envs.registration import register

import torch as th
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback

import matplotlib.pyplot as plt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 7.9 MB/s eta 0:00:00
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
class CartPoleSwingUpEnv(CartPoleEnv):
    def __init__(
        self,
        sutton_barto_reward: bool = False,
        render_mode: str | None = None,
        swing_up_reward: bool = True,
        terminate_on_fall: bool = False,  # 是否在杆子“掉下来”时终止
    ):
        super().__init__(sutton_barto_reward=sutton_barto_reward, render_mode=render_mode)

        # 关键：放宽终止角度阈值（原为 12° = 0.2094 rad）
        # 现在允许杆子自由旋转（±π），只在 cart 越界或极端角度终止
        self.theta_threshold_radians = math.pi  # 几乎永不因角度终止
        self.x_threshold = 2.4  # 保留 cart 位置终止

        self.swing_up_reward = swing_up_reward
        self.terminate_on_fall = terminate_on_fall  # 可选：在 θ 接近 ±π 时终止

        # 更新 observation space 的 theta 范围（因为现在 θ ∈ [-π, π]）
        high = np.array([
            self.x_threshold * 2,
            np.inf,
            self.theta_threshold_radians,
            np.inf
        ], dtype=np.float32)
        self.observation_space = gym.spaces.Box(-high, high, dtype=np.float32)

    def step(self, action):
        # 调用父类 step：执行物理仿真（动力学不变！）
        obs, _, terminated, truncated, info = super().step(action)

        x, x_dot, theta, theta_dot = self.state # type: ignore

        # 规范化 theta 到 [-π, π]
        theta = ((theta + math.pi) % (2 * math.pi)) - math.pi
        self.state[2] = theta  # type: ignore # 更新 state 中的 theta

        # === 自定义奖励 ===
        if self.swing_up_reward:
            # cos(theta): θ=0 → 1（最优），θ=±π → -1（最差）
            # 映射到 [0, 1] 并鼓励稳定
            reward = (np.cos(theta) + 1) / 2  # ∈ [0, 1]
            # 可选：在上方稳定时加分（减少抖动）
            if abs(theta) < 0.1 and abs(theta_dot) < 0.5:
                reward += 1.0
        else:
            # 回退到原始奖励（一般不用）
            reward = 1.0

        # === 自定义终止条件 ===
        cart_terminated = bool(x < -self.x_threshold or x > self.x_threshold)
        angle_terminated = False
        if self.terminate_on_fall:
            # 如果杆子几乎完全朝下（±π ± 0.1），视为失败终止
            if abs(abs(theta) - math.pi) < 0.1:
                angle_terminated = True

        new_terminated = cart_terminated or angle_terminated

        # 注意：原 CartPole 的 terminated 是基于 ±12°，但我们重写了 theta_threshold，
        # 所以上面 super().step() 中的 terminated 已经失效（因为 theta_threshold = π）
        # 所以我们完全用自己的 terminated 逻辑

        return np.array(self.state, dtype=np.float32), reward, new_terminated, truncated, info


    def reset(self, *, seed: int | None = None, options: dict | None = None):
        super().reset(seed=seed, options=options)

        # 确保从“朝下”开始：theta ≈ ±π，但统一规范化为接近 -π
        # 方法：采样偏移后直接规范化
        theta_init = self.np_random.uniform(-0.1, 0.1)  # 小扰动
        theta_down = math.pi + theta_init  # 先设为 π + noise

        # 立即规范化到 [-π, π)
        theta_down = ((theta_down + math.pi) % (2 * math.pi)) - math.pi

        self.state = np.array([
            self.np_random.uniform(-0.1, 0.1),      # x
            self.np_random.uniform(-0.1, 0.1),      # x_dot
            theta_down,                             # theta (朝下，≈ ±π → 实际 ≈ -π)
            self.np_random.uniform(-0.1, 0.1)       # theta_dot
        ], dtype=np.float64)

        self.steps_beyond_terminated = None
        return np.array(self.state, dtype=np.float32), {}


register(
    id="CartPoleSwingUp-v0",
    entry_point="__main__:CartPoleSwingUpEnv",  # 注意这里是 __main__
    max_episode_steps=500,
    kwargs={
        "swing_up_reward": True,
        "terminate_on_fall": False,
    },
)

# %%
class EpisodeRewardCallback(BaseCallback):
    def __init__(self, log_every=500):
        super().__init__()
        self.log_every = log_every
        self.all_rewards = []
        self._n_episodes = 0

    def _on_training_start(self) -> None:
        env = self.training_env
        self.n_envs = env.num_envs
        self.episode_rewards = np.zeros(self.n_envs)

    def _on_step(self) -> bool:
        infos = self.locals["infos"]
        rewards = self.locals["rewards"]

        # accumulate rewards for each environment
        self.episode_rewards += rewards

        for i, info in enumerate(infos):
            if "episode" in info:
                ep_reward = info["episode"]["r"]
                self._n_episodes += 1
                self.all_rewards.append(ep_reward)

                if self._n_episodes % self.log_every == 0:
                    print(f"Episode {self._n_episodes}: reward = {ep_reward}")

                # reset this env's accumulator
                self.episode_rewards[i] = 0.0

        return True

# %%
policy_kwargs = dict(
    net_arch=[5, 5],           # shared hidden layers: 4 -> 5 -> 5
    activation_fn=th.nn.ReLU,  # same activation
)

env_id = "CartPoleSwingUp-v0"
n_envs = 8
vec_env = make_vec_env(env_id, n_envs=n_envs)

model = PPO(
    policy="MlpPolicy",
    env=vec_env,
    policy_kwargs=policy_kwargs,
    verbose=1,
)

max_episode_steps = 500
total_timesteps = 5000 * max_episode_steps  # ~1000 episodes

callback = EpisodeRewardCallback(log_every=1)

model.learn(
    total_timesteps=total_timesteps,
    callback=callback
)

print("Training finished.")
# Out:
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/classic_control/cartpole.py:214: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Episode 3022: reward = 312.467679
# Episode 3023: reward = 312.603313
# Episode 3024: reward = 436.74555
# Episode 3025: reward = 312.180195
# Episode 3026: reward = 247.301696
# Episode 3027: reward = 366.683247
# Episode 3028: reward = 313.699202
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 435          |
# |    ep_rew_mean          | 303          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 67           |
# |    time_elapsed         | 988          |
# |    total_timesteps      | 1097728      |
# | train/                  |              |
# |    approx_kl            | 0.0021349518 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | 0.627        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.9         |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 36.2         |
# ------------------------------------------
# Episode 3029: reward = 173.918253
# Episode 3030: reward = 233.357198
# Episode 3031: reward = 427.222876
# Episode 3032: reward = 130.370549
# Episode 3033: reward = 293.69804
# Episode 3034: reward = 330.92121
# Episode 3035: reward = 308.100149
# Episode 3036: reward = 161.166267
# Episode 3037: reward = 434.317722
# Episode 3038: reward = 298.499236
# Episode 3039: reward = 316.760058
# Episode 3040: reward = 347.27202
# Episode 3041: reward = 318.971753
# Episode 3042: reward = 280.855351
# Episode 3043: reward = 281.990418
# Episode 3044: reward = 304.422904
# Episode 3045: reward = 486.731295
# Episode 3046: reward = 196.680213
# Episode 3047: reward = 489.35424
# Episode 3048: reward = 345.917382
# Episode 3049: reward = 243.896178
# Episode 3050: reward = 230.858579
# Episode 3051: reward = 220.597778
# Episode 3052: reward = 264.719763
# Episode 3053: reward = 305.164073
# Episode 3054: reward = 321.66118
# Episode 3055: reward = 188.49415
# Episode 3056: reward = 298.675712
# Episode 3057: reward = 449.613476
# Episode 3058: reward = 73.863647
# Episode 3059: reward = 318.682916
# Episode 3060: reward = 352.174542
# Episode 3061: reward = 345.398597
# Episode 3062: reward = 338.380721
# Episode 3063: reward = 153.53275
# Episode 3064: reward = 393.392266
# Episode 3065: reward = 174.498093
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 426          |
# |    ep_rew_mean          | 299          |
# | time/                   |              |
# |    fps                  | 1111         |
# |    iterations           | 68           |
# |    time_elapsed         | 1002         |
# |    total_timesteps      | 1114112      |
# | train/                  |              |
# |    approx_kl            | 0.0036669357 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | 0.672        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 93.1         |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 35.7         |
# ------------------------------------------
# Episode 3066: reward = 363.803033
# Episode 3067: reward = 331.450314
# Episode 3068: reward = 414.393194
# Episode 3069: reward = 164.591422
# Episode 3070: reward = 193.670379
# Episode 3071: reward = 83.948179
# Episode 3072: reward = 241.200282
# Episode 3073: reward = 335.221566
# Episode 3074: reward = 385.024318
# Episode 3075: reward = 321.364414
# Episode 3076: reward = 410.989428
# Episode 3077: reward = 339.301235
# Episode 3078: reward = 308.01048
# Episode 3079: reward = 320.842181
# Episode 3080: reward = 339.889539
# Episode 3081: reward = 372.611934
# Episode 3082: reward = 358.664387
# Episode 3083: reward = 364.574425
# Episode 3084: reward = 330.312911
# Episode 3085: reward = 262.135241
# Episode 3086: reward = 331.511456
# Episode 3087: reward = 353.14409
# Episode 3088: reward = 304.970896
# Episode 3089: reward = 400.12364
# Episode 3090: reward = 11.499193
# Episode 3091: reward = 421.47685
# Episode 3092: reward = 324.077767
# Episode 3093: reward = 324.0239
# Episode 3094: reward = 448.686407
# Episode 3095: reward = 410.088275
# Episode 3096: reward = 345.550035
# Episode 3097: reward = 398.943691
# Episode 3098: reward = 70.402024
# Episode 3099: reward = 323.248905
# Episode 3100: reward = 344.353306
# Episode 3101: reward = 335.644395
# Episode 3102: reward = 72.300229
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 439         |
# |    ep_rew_mean          | 307         |
# | time/                   |             |
# |    fps                  | 1111        |
# |    iterations           | 69          |
# |    time_elapsed         | 1017        |
# |    total_timesteps      | 1130496     |
# | train/                  |             |
# |    approx_kl            | 0.003210318 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27          |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 59.8        |
# -----------------------------------------
# Episode 3103: reward = 304.236494
# Episode 3104: reward = 320.04953
# Episode 3105: reward = 408.881009
# Episode 3106: reward = 456.113102
# Episode 3107: reward = 347.826422
# Episode 3108: reward = 326.706739
# Episode 3109: reward = 340.766783
# Episode 3110: reward = 422.890649
# Episode 3111: reward = 204.407682
# Episode 3112: reward = 392.438624
# Episode 3113: reward = 314.642358
# Episode 3114: reward = 295.784082
# Episode 3115: reward = 301.709517
# Episode 3116: reward = 458.157269
# Episode 3117: reward = 334.086848
# Episode 3118: reward = 201.574214
# Episode 3119: reward = 306.77528
# Episode 3120: reward = 507.595479
# Episode 3121: reward = 66.825024
# Episode 3122: reward = 358.886269
# Episode 3123: reward = 74.085842
# Episode 3124: reward = 359.123531
# Episode 3125: reward = 344.877622
# Episode 3126: reward = 314.126323
# Episode 3127: reward = 77.974831
# Episode 3128: reward = 354.931657
# Episode 3129: reward = 403.828528
# Episode 3130: reward = 168.26902
# Episode 3131: reward = 319.136798
# Episode 3132: reward = 352.241725
# Episode 3133: reward = 67.53741
# Episode 3134: reward = 436.131128
# Episode 3135: reward = 302.894453
# Episode 3136: reward = 321.934895
# Episode 3137: reward = 396.450139
# Episode 3138: reward = 312.39278
# Episode 3139: reward = 412.233839
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | 309         |
# | time/                   |             |
# |    fps                  | 1111        |
# |    iterations           | 70          |
# |    time_elapsed         | 1031        |
# |    total_timesteps      | 1146880     |
# | train/                  |             |
# |    approx_kl            | 0.003093244 |
# |    clip_fraction        | 0.0141      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.5        |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 36.5        |
# -----------------------------------------
# Episode 3140: reward = 416.440002
# Episode 3141: reward = 97.118663
# Episode 3142: reward = 81.099803
# Episode 3143: reward = 345.30408
# Episode 3144: reward = 89.372601
# Episode 3145: reward = 332.318919
# Episode 3146: reward = 288.029879
# Episode 3147: reward = 427.489052
# Episode 3148: reward = 83.579127
# Episode 3149: reward = 363.986419
# Episode 3150: reward = 391.763562
# Episode 3151: reward = 348.204797
# Episode 3152: reward = 396.246557
# Episode 3153: reward = 359.630885
# Episode 3154: reward = 75.652912
# Episode 3155: reward = 79.949787
# Episode 3156: reward = 10.494585
# Episode 3157: reward = 295.279282
# Episode 3158: reward = 327.637253
# Episode 3159: reward = 345.748635
# Episode 3160: reward = 493.868679
# Episode 3161: reward = 347.319348
# Episode 3162: reward = 253.653265
# Episode 3163: reward = 348.665819
# Episode 3164: reward = 349.729261
# Episode 3165: reward = 419.518676
# Episode 3166: reward = 410.667388
# Episode 3167: reward = 334.103282
# Episode 3168: reward = 359.711048
# Episode 3169: reward = 361.254294
# Episode 3170: reward = 353.622286
# Episode 3171: reward = 149.47945
# Episode 3172: reward = 307.43809
# Episode 3173: reward = 383.608842
# Episode 3174: reward = 330.155741
# Episode 3175: reward = 342.139309
# Episode 3176: reward = 316.787865
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 436          |
# |    ep_rew_mean          | 309          |
# | time/                   |              |
# |    fps                  | 1111         |
# |    iterations           | 71           |
# |    time_elapsed         | 1046         |
# |    total_timesteps      | 1163264      |
# | train/                  |              |
# |    approx_kl            | 0.0025960514 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.441       |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 36.6         |
# ------------------------------------------
# Episode 3177: reward = 317.198184
# Episode 3178: reward = 377.75353
# Episode 3179: reward = 378.023645
# Episode 3180: reward = 347.213936
# Episode 3181: reward = 314.52183
# Episode 3182: reward = 113.236016
# Episode 3183: reward = 339.483777
# Episode 3184: reward = 466.069784
# Episode 3185: reward = 318.917882
# Episode 3186: reward = 312.852917
# Episode 3187: reward = 381.517788
# Episode 3188: reward = 440.289663
# Episode 3189: reward = 348.598621
# Episode 3190: reward = 416.531047
# Episode 3191: reward = 343.546817
# Episode 3192: reward = 284.032236
# Episode 3193: reward = 301.099064
# Episode 3194: reward = 327.330021
# Episode 3195: reward = 359.615818
# Episode 3196: reward = 345.110817
# Episode 3197: reward = 367.386549
# Episode 3198: reward = 389.188547
# Episode 3199: reward = 350.520371
# Episode 3200: reward = 355.457276
# Episode 3201: reward = 10.527193
# Episode 3202: reward = 430.607108
# Episode 3203: reward = 381.4413
# Episode 3204: reward = 394.669192
# Episode 3205: reward = 416.281893
# Episode 3206: reward = 339.250467
# Episode 3207: reward = 380.293178
# Episode 3208: reward = 327.887882
# Episode 3209: reward = 347.058171
# Episode 3210: reward = 417.192711
# Episode 3211: reward = 10.772967
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 439          |
# |    ep_rew_mean          | 313          |
# | time/                   |              |
# |    fps                  | 1111         |
# |    iterations           | 72           |
# |    time_elapsed         | 1061         |
# |    total_timesteps      | 1179648      |
# | train/                  |              |
# |    approx_kl            | 0.0028481514 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.4         |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.00125     |
# |    value_loss           | 32.5         |
# ------------------------------------------
# Episode 3212: reward = 464.411378
# Episode 3213: reward = 344.109536
# Episode 3214: reward = 405.495552
# Episode 3215: reward = 302.159531
# Episode 3216: reward = 340.634027
# Episode 3217: reward = 319.327658
# Episode 3218: reward = 434.462345
# Episode 3219: reward = 85.147766
# Episode 3220: reward = 78.973272
# Episode 3221: reward = 331.733473
# Episode 3222: reward = 241.639699
# Episode 3223: reward = 287.479141
# Episode 3224: reward = 91.936351
# Episode 3225: reward = 384.526149
# Episode 3226: reward = 393.088061
# Episode 3227: reward = 374.135885
# Episode 3228: reward = 368.38637
# Episode 3229: reward = 347.819922
# Episode 3230: reward = 392.108218
# Episode 3231: reward = 385.617465
# Episode 3232: reward = 351.728431
# Episode 3233: reward = 377.045608
# Episode 3234: reward = 410.175944
# Episode 3235: reward = 422.693351
# Episode 3236: reward = 74.242496
# Episode 3237: reward = 349.508653
# Episode 3238: reward = 347.880913
# Episode 3239: reward = 84.323983
# Episode 3240: reward = 151.261166
# Episode 3241: reward = 77.06785
# Episode 3242: reward = 287.793384
# Episode 3243: reward = 211.33076
# Episode 3244: reward = 179.223052
# Episode 3245: reward = 186.019146
# Episode 3246: reward = 337.200166
# Episode 3247: reward = 344.62257
# Episode 3248: reward = 419.356911
# Episode 3249: reward = 352.446708
# Episode 3250: reward = 454.988776
# Episode 3251: reward = 413.899192
# Episode 3252: reward = 70.307461
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 438       |
# |    ep_rew_mean          | 314       |
# | time/                   |           |
# |    fps                  | 1110      |
# |    iterations           | 73        |
# |    time_elapsed         | 1076      |
# |    total_timesteps      | 1196032   |
# | train/                  |           |
# |    approx_kl            | 0.0038163 |
# |    clip_fraction        | 0.0254    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.445    |
# |    explained_variance   | 0.782     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 12.8      |
# |    n_updates            | 720       |
# |    policy_gradient_loss | -0.00214  |
# |    value_loss           | 27.8      |
# ---------------------------------------
# Episode 3253: reward = 338.958323
# Episode 3254: reward = 365.955267
# Episode 3255: reward = 435.983233
# Episode 3256: reward = 70.087356
# Episode 3257: reward = 316.961772
# Episode 3258: reward = 71.234672
# Episode 3259: reward = 413.778097
# Episode 3260: reward = 511.425339
# Episode 3261: reward = 482.89726
# Episode 3262: reward = 412.424731
# Episode 3263: reward = 389.180213
# Episode 3264: reward = 385.24827
# Episode 3265: reward = 503.050396
# Episode 3266: reward = 385.411461
# Episode 3267: reward = 301.039553
# Episode 3268: reward = 409.855232
# Episode 3269: reward = 335.099626
# Episode 3270: reward = 329.366436
# Episode 3271: reward = 381.145482
# Episode 3272: reward = 393.213725
# Episode 3273: reward = 412.458431
# Episode 3274: reward = 362.689137
# Episode 3275: reward = 434.477703
# Episode 3276: reward = 386.323465
# Episode 3277: reward = 358.350258
# Episode 3278: reward = 399.590469
# Episode 3279: reward = 436.796578
# Episode 3280: reward = 419.526813
# Episode 3281: reward = 379.996534
# Episode 3282: reward = 351.151574
# Episode 3283: reward = 276.599813
# Episode 3284: reward = 391.451772
# Episode 3285: reward = 363.542441
# Episode 3286: reward = 386.599292
# Episode 3287: reward = 436.631956
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 448         |
# |    ep_rew_mean          | 334         |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 74          |
# |    time_elapsed         | 1091        |
# |    total_timesteps      | 1212416     |
# | train/                  |             |
# |    approx_kl            | 0.002533532 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 37.4        |
# -----------------------------------------
# Episode 3288: reward = 69.751623
# Episode 3289: reward = 379.518472
# Episode 3290: reward = 444.53826
# Episode 3291: reward = 380.717776
# Episode 3292: reward = 352.127933
# Episode 3293: reward = 361.073894
# Episode 3294: reward = 387.646594
# Episode 3295: reward = 387.65557
# Episode 3296: reward = 313.25982
# Episode 3297: reward = 413.406361
# Episode 3298: reward = 451.936601
# Episode 3299: reward = 322.818166
# Episode 3300: reward = 402.411045
# Episode 3301: reward = 314.625088
# Episode 3302: reward = 451.90518
# Episode 3303: reward = 531.785399
# Episode 3304: reward = 370.028516
# Episode 3305: reward = 358.214174
# Episode 3306: reward = 442.654424
# Episode 3307: reward = 404.174076
# Episode 3308: reward = 455.780836
# Episode 3309: reward = 399.970959
# Episode 3310: reward = 348.598551
# Episode 3311: reward = 398.026952
# Episode 3312: reward = 393.286276
# Episode 3313: reward = 392.725891
# Episode 3314: reward = 449.702089
# Episode 3315: reward = 74.009119
# Episode 3316: reward = 362.232675
# Episode 3317: reward = 419.437347
# Episode 3318: reward = 394.772524
# Episode 3319: reward = 180.78449
# Episode 3320: reward = 372.962059
# Episode 3321: reward = 406.422634
# Episode 3322: reward = 439.870101
# Episode 3323: reward = 473.080599
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 455         |
# |    ep_rew_mean          | 352         |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 75          |
# |    time_elapsed         | 1106        |
# |    total_timesteps      | 1228800     |
# | train/                  |             |
# |    approx_kl            | 0.003324972 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.444      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.1        |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.00204    |
# |    value_loss           | 29.2        |
# -----------------------------------------
# Episode 3324: reward = 411.997228
# Episode 3325: reward = 459.689475
# Episode 3326: reward = 372.630968
# Episode 3327: reward = 374.411268
# Episode 3328: reward = 413.328144
# Episode 3329: reward = 489.130039
# Episode 3330: reward = 444.473158
# Episode 3331: reward = 477.228184
# Episode 3332: reward = 363.679814
# Episode 3333: reward = 435.750823
# Episode 3334: reward = 403.590402
# Episode 3335: reward = 441.436653
# Episode 3336: reward = 352.771907
# Episode 3337: reward = 408.457344
# Episode 3338: reward = 10.426636
# Episode 3339: reward = 542.037295
# Episode 3340: reward = 361.040044
# Episode 3341: reward = 400.911178
# Episode 3342: reward = 479.414063
# Episode 3343: reward = 355.930484
# Episode 3344: reward = 446.747376
# Episode 3345: reward = 463.062468
# Episode 3346: reward = 443.33735
# Episode 3347: reward = 371.904169
# Episode 3348: reward = 488.625156
# Episode 3349: reward = 384.443526
# Episode 3350: reward = 74.450555
# Episode 3351: reward = 69.525622
# Episode 3352: reward = 379.33532
# Episode 3353: reward = 75.827597
# Episode 3354: reward = 79.934559
# Episode 3355: reward = 353.965867
# Episode 3356: reward = 464.784263
# Episode 3357: reward = 68.910142
# Episode 3358: reward = 516.129954
# Episode 3359: reward = 414.244659
# Episode 3360: reward = 514.544463
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 466          |
# |    ep_rew_mean          | 376          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 76           |
# |    time_elapsed         | 1121         |
# |    total_timesteps      | 1245184      |
# | train/                  |              |
# |    approx_kl            | 0.0031879854 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.443       |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.2         |
# |    n_updates            | 750          |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 34.1         |
# ------------------------------------------
# Episode 3361: reward = 391.184811
# Episode 3362: reward = 244.006603
# Episode 3363: reward = 437.084982
# Episode 3364: reward = 185.031553
# Episode 3365: reward = 282.534583
# Episode 3366: reward = 394.32519
# Episode 3367: reward = 362.081849
# Episode 3368: reward = 379.531663
# Episode 3369: reward = 531.620974
# Episode 3370: reward = 363.162908
# Episode 3371: reward = 524.681903
# Episode 3372: reward = 638.837033
# Episode 3373: reward = 514.362824
# Episode 3374: reward = 371.246417
# Episode 3375: reward = 545.330096
# Episode 3376: reward = 11.022468
# Episode 3377: reward = 463.446992
# Episode 3378: reward = 274.959096
# Episode 3379: reward = 194.970959
# Episode 3380: reward = 69.734111
# Episode 3381: reward = 342.455386
# Episode 3382: reward = 193.899311
# Episode 3383: reward = 471.952713
# Episode 3384: reward = 480.991365
# Episode 3385: reward = 437.831539
# Episode 3386: reward = 69.43832
# Episode 3387: reward = 348.004515
# Episode 3388: reward = 391.161948
# Episode 3389: reward = 471.215274
# Episode 3390: reward = 414.728356
# Episode 3391: reward = 160.4371
# Episode 3392: reward = 450.414108
# Episode 3393: reward = 285.172203
# Episode 3394: reward = 148.570796
# Episode 3395: reward = 382.820082
# Episode 3396: reward = 528.057867
# Episode 3397: reward = 134.378519
# Episode 3398: reward = 403.704465
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | 365          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 77           |
# |    time_elapsed         | 1136         |
# |    total_timesteps      | 1261568      |
# | train/                  |              |
# |    approx_kl            | 0.0038051675 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.7         |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.00351     |
# |    value_loss           | 40.1         |
# ------------------------------------------
# Episode 3399: reward = 441.442826
# Episode 3400: reward = 165.67284
# Episode 3401: reward = 300.954536
# Episode 3402: reward = 353.320478
# Episode 3403: reward = 372.696923
# Episode 3404: reward = 399.163837
# Episode 3405: reward = 462.350161
# Episode 3406: reward = 74.468972
# Episode 3407: reward = 405.707292
# Episode 3408: reward = 452.63383
# Episode 3409: reward = 323.547793
# Episode 3410: reward = 575.563491
# Episode 3411: reward = 551.438081
# Episode 3412: reward = 554.445731
# Episode 3413: reward = 486.339917
# Episode 3414: reward = 342.57827
# Episode 3415: reward = 269.629628
# Episode 3416: reward = 67.652838
# Episode 3417: reward = 134.43639
# Episode 3418: reward = 524.957951
# Episode 3419: reward = 455.401891
# Episode 3420: reward = 367.84316
# Episode 3421: reward = 59.77755
# Episode 3422: reward = 342.082643
# Episode 3423: reward = 437.16741
# Episode 3424: reward = 426.433014
# Episode 3425: reward = 398.801445
# Episode 3426: reward = 532.562395
# Episode 3427: reward = 121.320172
# Episode 3428: reward = 94.505334
# Episode 3429: reward = 225.505665
# Episode 3430: reward = 427.831328
# Episode 3431: reward = 365.908697
# Episode 3432: reward = 332.602699
# Episode 3433: reward = 219.856664
# Episode 3434: reward = 459.877679
# Episode 3435: reward = 212.092954
# Episode 3436: reward = 481.768293
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 412          |
# |    ep_rew_mean          | 347          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 78           |
# |    time_elapsed         | 1150         |
# |    total_timesteps      | 1277952      |
# | train/                  |              |
# |    approx_kl            | 0.0036828597 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.44        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 64.9         |
# ------------------------------------------
# Episode 3437: reward = 449.673644
# Episode 3438: reward = 476.380609
# Episode 3439: reward = 503.853423
# Episode 3440: reward = 408.30212
# Episode 3441: reward = 9.216677
# Episode 3442: reward = 72.119445
# Episode 3443: reward = 347.947762
# Episode 3444: reward = 383.185425
# Episode 3445: reward = 477.71058
# Episode 3446: reward = 97.067702
# Episode 3447: reward = 185.318681
# Episode 3448: reward = 603.093868
# Episode 3449: reward = 557.268272
# Episode 3450: reward = 420.810094
# Episode 3451: reward = 445.213638
# Episode 3452: reward = 237.1715
# Episode 3453: reward = 213.850275
# Episode 3454: reward = 69.649662
# Episode 3455: reward = 12.259466
# Episode 3456: reward = 9.827214
# Episode 3457: reward = 399.318835
# Episode 3458: reward = 175.633051
# Episode 3459: reward = 124.886081
# Episode 3460: reward = 409.238893
# Episode 3461: reward = 492.394797
# Episode 3462: reward = 545.559796
# Episode 3463: reward = 284.652443
# Episode 3464: reward = 419.464223
# Episode 3465: reward = 514.933734
# Episode 3466: reward = 78.493378
# Episode 3467: reward = 446.566542
# Episode 3468: reward = 297.727678
# Episode 3469: reward = 278.096949
# Episode 3470: reward = 315.013307
# Episode 3471: reward = 341.559981
# Episode 3472: reward = 11.45104
# Episode 3473: reward = 136.528162
# Episode 3474: reward = 411.946201
# Episode 3475: reward = 345.437048
# Episode 3476: reward = 361.546103
# Episode 3477: reward = 350.411642
# Episode 3478: reward = 12.406854
# Episode 3479: reward = 304.500873
# Episode 3480: reward = 71.284401
# Episode 3481: reward = 471.598957
# Episode 3482: reward = 305.742578
# Episode 3483: reward = 60.243184
# Episode 3484: reward = 245.438649
# Episode 3485: reward = 57.31445
# Episode 3486: reward = 11.851047
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | 316          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 79           |
# |    time_elapsed         | 1165         |
# |    total_timesteps      | 1294336      |
# | train/                  |              |
# |    approx_kl            | 0.0035783886 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.446       |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.6         |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 71.6         |
# ------------------------------------------
# Episode 3487: reward = 178.864885
# Episode 3488: reward = 68.075799
# Episode 3489: reward = 86.49854
# Episode 3490: reward = 539.839835
# Episode 3491: reward = 335.426387
# Episode 3492: reward = 138.098725
# Episode 3493: reward = 397.680543
# Episode 3494: reward = 11.240643
# Episode 3495: reward = 382.180205
# Episode 3496: reward = 153.637771
# Episode 3497: reward = 150.109516
# Episode 3498: reward = 480.452566
# Episode 3499: reward = 527.655295
# Episode 3500: reward = 544.922891
# Episode 3501: reward = 102.17491
# Episode 3502: reward = 293.589977
# Episode 3503: reward = 644.436294
# Episode 3504: reward = 51.764046
# Episode 3505: reward = 446.837025
# Episode 3506: reward = 496.118929
# Episode 3507: reward = 596.359512
# Episode 3508: reward = 70.212081
# Episode 3509: reward = 62.510343
# Episode 3510: reward = 93.562231
# Episode 3511: reward = 502.273917
# Episode 3512: reward = 176.534609
# Episode 3513: reward = 128.750622
# Episode 3514: reward = 199.204372
# Episode 3515: reward = 406.039094
# Episode 3516: reward = 300.778618
# Episode 3517: reward = 252.278558
# Episode 3518: reward = 8.734876
# Episode 3519: reward = 553.158207
# Episode 3520: reward = 521.189127
# Episode 3521: reward = 31.331929
# Episode 3522: reward = 471.29763
# Episode 3523: reward = 83.251375
# Episode 3524: reward = 136.994364
# Episode 3525: reward = 484.442712
# Episode 3526: reward = 613.276005
# Episode 3527: reward = 440.600307
# Episode 3528: reward = 453.47553
# Episode 3529: reward = 375.519707
# Episode 3530: reward = 509.66212
# Episode 3531: reward = 9.999442
# Episode 3532: reward = 136.253004
# Episode 3533: reward = 537.404875
# Episode 3534: reward = 623.835487
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 352         |
# |    ep_rew_mean          | 298         |
# | time/                   |             |
# |    fps                  | 1109        |
# |    iterations           | 80          |
# |    time_elapsed         | 1180        |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.003966311 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.418      |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.6        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 100         |
# -----------------------------------------
# Episode 3535: reward = 654.161909
# Episode 3536: reward = 487.127126
# Episode 3537: reward = 11.027754
# Episode 3538: reward = 105.62367
# Episode 3539: reward = 179.900432
# Episode 3540: reward = 198.661373
# Episode 3541: reward = 196.981471
# Episode 3542: reward = 164.332694
# Episode 3543: reward = 170.340004
# Episode 3544: reward = 11.346505
# Episode 3545: reward = 371.609999
# Episode 3546: reward = 580.136054
# Episode 3547: reward = 85.475515
# Episode 3548: reward = 180.974985
# Episode 3549: reward = 125.012411
# Episode 3550: reward = 195.843697
# Episode 3551: reward = 606.885619
# Episode 3552: reward = 171.864387
# Episode 3553: reward = 233.674394
# Episode 3554: reward = 283.848053
# Episode 3555: reward = 455.469745
# Episode 3556: reward = 141.482925
# Episode 3557: reward = 168.453399
# Episode 3558: reward = 365.284647
# Episode 3559: reward = 329.27414
# Episode 3560: reward = 63.996432
# Episode 3561: reward = 337.382985
# Episode 3562: reward = 112.715009
# Episode 3563: reward = 73.899055
# Episode 3564: reward = 514.569827
# Episode 3565: reward = 699.139476
# Episode 3566: reward = 660.95485
# Episode 3567: reward = 219.456698
# Episode 3568: reward = 321.929711
# Episode 3569: reward = 569.715196
# Episode 3570: reward = 71.977845
# Episode 3571: reward = 174.375957
# Episode 3572: reward = 392.681341
# Episode 3573: reward = 50.57221
# Episode 3574: reward = 275.904427
# Episode 3575: reward = 43.346213
# Episode 3576: reward = 8.811101
# Episode 3577: reward = 174.210429
# Episode 3578: reward = 90.628108
# Episode 3579: reward = 161.75977
# Episode 3580: reward = 440.2259
# Episode 3581: reward = 192.920167
# Episode 3582: reward = 85.154438
# Episode 3583: reward = 10.202567
# Episode 3584: reward = 740.491318
# Episode 3585: reward = 142.044798
# Episode 3586: reward = 98.462012
# Episode 3587: reward = 177.438157
# Episode 3588: reward = 80.484697
# Episode 3589: reward = 140.034626
# Episode 3590: reward = 113.780326
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 318         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 1109        |
# |    iterations           | 81          |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 1327104     |
# | train/                  |             |
# |    approx_kl            | 0.004036024 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 96.8        |
# -----------------------------------------
# Episode 3591: reward = 235.188027
# Episode 3592: reward = 548.093693
# Episode 3593: reward = 164.97641
# Episode 3594: reward = 354.285609
# Episode 3595: reward = 499.773783
# Episode 3596: reward = 75.080256
# Episode 3597: reward = 62.054146
# Episode 3598: reward = 331.18658
# Episode 3599: reward = 215.260639
# Episode 3600: reward = 291.40899
# Episode 3601: reward = 68.225488
# Episode 3602: reward = 436.201486
# Episode 3603: reward = 611.639765
# Episode 3604: reward = 101.856292
# Episode 3605: reward = 394.576253
# Episode 3606: reward = 141.491426
# Episode 3607: reward = 163.240508
# Episode 3608: reward = 96.329579
# Episode 3609: reward = 567.054597
# Episode 3610: reward = 81.339729
# Episode 3611: reward = 282.278122
# Episode 3612: reward = 68.548852
# Episode 3613: reward = 563.242907
# Episode 3614: reward = 135.099596
# Episode 3615: reward = 641.640411
# Episode 3616: reward = 455.540216
# Episode 3617: reward = 279.480057
# Episode 3618: reward = 626.85931
# Episode 3619: reward = 420.96837
# Episode 3620: reward = 472.126459
# Episode 3621: reward = 61.152044
# Episode 3622: reward = 198.136839
# Episode 3623: reward = 205.84748
# Episode 3624: reward = 498.166578
# Episode 3625: reward = 435.688146
# Episode 3626: reward = 90.605143
# Episode 3627: reward = 12.010676
# Episode 3628: reward = 390.405593
# Episode 3629: reward = 272.949193
# Episode 3630: reward = 9.898573
# Episode 3631: reward = 497.323148
# Episode 3632: reward = 10.381644
# Episode 3633: reward = 510.305663
# Episode 3634: reward = 70.625887
# Episode 3635: reward = 125.084042
# Episode 3636: reward = 409.028402
# Episode 3637: reward = 158.915924
# Episode 3638: reward = 544.305732
# Episode 3639: reward = 231.621135
# Episode 3640: reward = 499.776278
# Episode 3641: reward = 98.113331
# Episode 3642: reward = 507.76683
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 269          |
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 82           |
# |    time_elapsed         | 1211         |
# |    total_timesteps      | 1343488      |
# | train/                  |              |
# |    approx_kl            | 0.0023217937 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.408       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 54.5         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.000802    |
# |    value_loss           | 130          |
# ------------------------------------------
# Episode 3643: reward = 458.323359
# Episode 3644: reward = 107.697682
# Episode 3645: reward = 86.721723
# Episode 3646: reward = 522.333082
# Episode 3647: reward = 449.809156
# Episode 3648: reward = 202.055532
# Episode 3649: reward = 11.531343
# Episode 3650: reward = 52.030807
# Episode 3651: reward = 545.120795
# Episode 3652: reward = 197.575161
# Episode 3653: reward = 131.155551
# Episode 3654: reward = 90.832575
# Episode 3655: reward = 668.491655
# Episode 3656: reward = 10.779026
# Episode 3657: reward = 58.3949
# Episode 3658: reward = 460.618099
# Episode 3659: reward = 562.329437
# Episode 3660: reward = 186.129255
# Episode 3661: reward = 377.016582
# Episode 3662: reward = 641.105434
# Episode 3663: reward = 490.349065
# Episode 3664: reward = 79.220482
# Episode 3665: reward = 477.403929
# Episode 3666: reward = 326.926838
# Episode 3667: reward = 239.739487
# Episode 3668: reward = 442.764635
# Episode 3669: reward = 12.793013
# Episode 3670: reward = 67.199302
# Episode 3671: reward = 12.398326
# Episode 3672: reward = 256.396426
# Episode 3673: reward = 343.893548
# Episode 3674: reward = 317.260775
# Episode 3675: reward = 509.04158
# Episode 3676: reward = 231.782565
# Episode 3677: reward = 578.112714
# Episode 3678: reward = 658.71764
# Episode 3679: reward = 103.284066
# Episode 3680: reward = 494.312826
# Episode 3681: reward = 276.628035
# Episode 3682: reward = 104.900551
# Episode 3683: reward = 191.551923
# Episode 3684: reward = 539.719478
# Episode 3685: reward = 351.912778
# Episode 3686: reward = 102.32697
# Episode 3687: reward = 284.081024
# Episode 3688: reward = 326.013622
# Episode 3689: reward = 602.907448
# Episode 3690: reward = 440.616756
# Episode 3691: reward = 524.136407
# Episode 3692: reward = 78.544062
# Episode 3693: reward = 9.80453
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 318          |
# |    ep_rew_mean          | 296          |
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 83           |
# |    time_elapsed         | 1225         |
# |    total_timesteps      | 1359872      |
# | train/                  |              |
# |    approx_kl            | 0.0030645188 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.422       |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52           |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 106          |
# ------------------------------------------
# Episode 3694: reward = 373.024282
# Episode 3695: reward = 94.480938
# Episode 3696: reward = 236.706266
# Episode 3697: reward = 532.779997
# Episode 3698: reward = 645.070096
# Episode 3699: reward = 10.087151
# Episode 3700: reward = 208.483897
# Episode 3701: reward = 661.682057
# Episode 3702: reward = 501.126487
# Episode 3703: reward = 85.887388
# Episode 3704: reward = 235.697331
# Episode 3705: reward = 608.943401
# Episode 3706: reward = 621.382131
# Episode 3707: reward = 140.09305
# Episode 3708: reward = 73.895476
# Episode 3709: reward = 369.496153
# Episode 3710: reward = 247.970696
# Episode 3711: reward = 554.905505
# Episode 3712: reward = 206.343623
# Episode 3713: reward = 273.309489
# Episode 3714: reward = 285.271457
# Episode 3715: reward = 543.65916
# Episode 3716: reward = 637.542829
# Episode 3717: reward = 537.866428
# Episode 3718: reward = 665.070342
# Episode 3719: reward = 93.812129
# Episode 3720: reward = 549.200193
# Episode 3721: reward = 282.100167
# Episode 3722: reward = 229.641636
# Episode 3723: reward = 494.862382
# Episode 3724: reward = 644.743157
# Episode 3725: reward = 505.208438
# Episode 3726: reward = 448.671735
# Episode 3727: reward = 611.261888
# Episode 3728: reward = 578.333275
# Episode 3729: reward = 502.73252
# Episode 3730: reward = 179.365219
# Episode 3731: reward = 79.150375
# Episode 3732: reward = 483.355495
# Episode 3733: reward = 232.360409
# Episode 3734: reward = 74.563092
# Episode 3735: reward = 593.334852
# Episode 3736: reward = 441.438541
# Episode 3737: reward = 511.809869
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 349          |
# |    ep_rew_mean          | 341          |
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 84           |
# |    time_elapsed         | 1240         |
# |    total_timesteps      | 1376256      |
# | train/                  |              |
# |    approx_kl            | 0.0027698032 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.422       |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.2         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 111          |
# ------------------------------------------
# Episode 3738: reward = 580.333587
# Episode 3739: reward = 245.892071
# Episode 3740: reward = 456.184396
# Episode 3741: reward = 567.316295
# Episode 3742: reward = 183.24008
# Episode 3743: reward = 322.404388
# Episode 3744: reward = 150.115043
# Episode 3745: reward = 512.294397
# Episode 3746: reward = 372.087036
# Episode 3747: reward = 620.807723
# Episode 3748: reward = 44.968921
# Episode 3749: reward = 138.545837
# Episode 3750: reward = 267.13825
# Episode 3751: reward = 648.07147
# Episode 3752: reward = 650.254251
# Episode 3753: reward = 614.981216
# Episode 3754: reward = 660.03429
# Episode 3755: reward = 350.687414
# Episode 3756: reward = 112.064435
# Episode 3757: reward = 253.387915
# Episode 3758: reward = 522.077927
# Episode 3759: reward = 670.050081
# Episode 3760: reward = 12.14846
# Episode 3761: reward = 132.983233
# Episode 3762: reward = 120.476484
# Episode 3763: reward = 32.785834
# Episode 3764: reward = 718.595994
# Episode 3765: reward = 229.417857
# Episode 3766: reward = 360.30333
# Episode 3767: reward = 349.974991
# Episode 3768: reward = 585.125245
# Episode 3769: reward = 503.339656
# Episode 3770: reward = 322.199408
# Episode 3771: reward = 197.988132
# Episode 3772: reward = 98.715565
# Episode 3773: reward = 507.800631
# Episode 3774: reward = 365.249886
# Episode 3775: reward = 93.898781
# Episode 3776: reward = 752.227509
# Episode 3777: reward = 152.12861
# Episode 3778: reward = 107.65019
# Episode 3779: reward = 741.961278
# Episode 3780: reward = 209.276032
# Episode 3781: reward = 588.01842
# Episode 3782: reward = 324.385884
# Episode 3783: reward = 234.349885
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 358          |
# |    ep_rew_mean          | 368          |
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 85           |
# |    time_elapsed         | 1255         |
# |    total_timesteps      | 1392640      |
# | train/                  |              |
# |    approx_kl            | 0.0044430643 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.438       |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.8         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00309     |
# |    value_loss           | 91           |
# ------------------------------------------
# Episode 3784: reward = 83.578633
# Episode 3785: reward = 183.852911
# Episode 3786: reward = 727.38643
# Episode 3787: reward = 742.147655
# Episode 3788: reward = 673.756733
# Episode 3789: reward = 187.008304
# Episode 3790: reward = 124.411337
# Episode 3791: reward = 349.953826
# Episode 3792: reward = 492.189244
# Episode 3793: reward = 348.794847
# Episode 3794: reward = 254.661424
# Episode 3795: reward = 97.099629
# Episode 3796: reward = 210.43935
# Episode 3797: reward = 132.821905
# Episode 3798: reward = 691.678305
# Episode 3799: reward = 703.01327
# Episode 3800: reward = 579.633834
# Episode 3801: reward = 744.064844
# Episode 3802: reward = 134.566103
# Episode 3803: reward = 628.133013
# Episode 3804: reward = 636.543671
# Episode 3805: reward = 722.656345
# Episode 3806: reward = 53.055109
# Episode 3807: reward = 139.809378
# Episode 3808: reward = 702.662592
# Episode 3809: reward = 564.967155
# Episode 3810: reward = 186.962012
# Episode 3811: reward = 312.004445
# Episode 3812: reward = 739.603451
# Episode 3813: reward = 319.915684
# Episode 3814: reward = 154.716154
# Episode 3815: reward = 203.558247
# Episode 3816: reward = 736.58837
# Episode 3817: reward = 243.491342
# Episode 3818: reward = 171.401526
# Episode 3819: reward = 589.305147
# Episode 3820: reward = 172.75658
# Episode 3821: reward = 32.999708
# Episode 3822: reward = 68.475398
# Episode 3823: reward = 214.143771
# Episode 3824: reward = 96.23608
# Episode 3825: reward = 728.560134
# Episode 3826: reward = 542.324431
# Episode 3827: reward = 10.692081
# Episode 3828: reward = 755.872529
# Episode 3829: reward = 669.579373
# Episode 3830: reward = 582.241586
# Episode 3831: reward = 82.340773
# Episode 3832: reward = 161.409039
# Episode 3833: reward = 220.342139
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 346          |
# |    ep_rew_mean          | 372          |
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 86           |
# |    time_elapsed         | 1270         |
# |    total_timesteps      | 1409024      |
# | train/                  |              |
# |    approx_kl            | 0.0038023284 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.5         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 97.9         |
# ------------------------------------------
# Episode 3834: reward = 252.655073
# Episode 3835: reward = 340.037897
# Episode 3836: reward = 319.236448
# Episode 3837: reward = 749.171717
# Episode 3838: reward = 721.612774
# Episode 3839: reward = 175.631806
# Episode 3840: reward = 772.641281
# Episode 3841: reward = 655.012098
# Episode 3842: reward = 572.417658
# Episode 3843: reward = 689.701941
# Episode 3844: reward = 747.527628
# Episode 3845: reward = 311.465551
# Episode 3846: reward = 87.849868
# Episode 3847: reward = 738.373164
# Episode 3848: reward = 247.382747
# Episode 3849: reward = 732.884455
# Episode 3850: reward = 669.27078
# Episode 3851: reward = 700.633089
# Episode 3852: reward = 712.39732
# Episode 3853: reward = 627.406911
# Episode 3854: reward = 675.123556
# Episode 3855: reward = 652.622094
# Episode 3856: reward = 132.945128
# Episode 3857: reward = 315.118748
# Episode 3858: reward = 747.354562
# Episode 3859: reward = 728.722348
# Episode 3860: reward = 698.424257
# Episode 3861: reward = 660.780963
# Episode 3862: reward = 250.275567
# Episode 3863: reward = 739.901492
# Episode 3864: reward = 279.026956
# Episode 3865: reward = 335.70094
# Episode 3866: reward = 239.339629
# Episode 3867: reward = 760.963641
# Episode 3868: reward = 189.30714
# Episode 3869: reward = 309.0301
# Episode 3870: reward = 714.558982
# Episode 3871: reward = 701.041925
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 366          |
# |    ep_rew_mean          | 430          |
# ...
# Episode 5935: reward = 829.380782
# Episode 5936: reward = 834.25775
# Episode 5937: reward = 824.089394
# Episode 5938: reward = 822.419161
# Episode 5939: reward = 830.543375
# Episode 5940: reward = 818.467678
# Episode 5941: reward = 799.309382
# Episode 5942: reward = 113.818373
# Episode 5943: reward = 825.755542
# Episode 5944: reward = 821.23059
# Episode 5945: reward = 824.930947
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 474          |
# |    ep_rew_mean          | 769          |
# | time/                   |              |
# |    fps                  | 1109         |
# |    iterations           | 146          |
# |    time_elapsed         | 2155         |
# |    total_timesteps      | 2392064      |
# | train/                  |              |
# |    approx_kl            | 0.0022563897 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.65         |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | 0.000397     |
# |    value_loss           | 26.9         |
# ------------------------------------------
# Episode 5946: reward = 829.189271
# Episode 5947: reward = 834.228677
# Episode 5948: reward = 824.36932
# Episode 5949: reward = 830.474677
# Episode 5950: reward = 828.237379
# Episode 5951: reward = 831.298692
# Episode 5952: reward = 807.850987
# Episode 5953: reward = 820.331187
# Episode 5954: reward = 826.141054
# Episode 5955: reward = 825.125063
# Episode 5956: reward = 821.208264
# Episode 5957: reward = 819.492601
# Episode 5958: reward = 822.556074
# Episode 5959: reward = 773.59715
# Episode 5960: reward = 173.487274
# Episode 5961: reward = 796.494962
# Episode 5962: reward = 827.838113
# Episode 5963: reward = 17.123437
# Episode 5964: reward = 827.712306
# Episode 5965: reward = 809.83799
# Episode 5966: reward = 828.108701
# Episode 5967: reward = 781.970285
# Episode 5968: reward = 18.018857
# Episode 5969: reward = 829.120025
# Episode 5970: reward = 779.793751
# Episode 5971: reward = 802.070797
# Episode 5972: reward = 824.26337
# Episode 5973: reward = 806.677173
# Episode 5974: reward = 821.139571
# Episode 5975: reward = 816.266265
# Episode 5976: reward = 762.734859
# Episode 5977: reward = 829.939279
# Episode 5978: reward = 827.480183
# Episode 5979: reward = 793.470863
# Episode 5980: reward = 817.842007
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 470          |
# |    ep_rew_mean          | 758          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 147          |
# |    time_elapsed         | 2169         |
# |    total_timesteps      | 2408448      |
# | train/                  |              |
# |    approx_kl            | 0.0015127745 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.65         |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | 9.36e-05     |
# |    value_loss           | 31.5         |
# ------------------------------------------
# Episode 5981: reward = 797.44739
# Episode 5982: reward = 828.195025
# Episode 5983: reward = 822.409936
# Episode 5984: reward = 799.577259
# Episode 5985: reward = 772.227393
# Episode 5986: reward = 823.65225
# Episode 5987: reward = 824.660083
# Episode 5988: reward = 829.710329
# Episode 5989: reward = 809.129281
# Episode 5990: reward = 827.781198
# Episode 5991: reward = 798.216617
# Episode 5992: reward = 788.950718
# Episode 5993: reward = 828.556408
# Episode 5994: reward = 803.251247
# Episode 5995: reward = 810.889719
# Episode 5996: reward = 802.802333
# Episode 5997: reward = 809.357041
# Episode 5998: reward = 821.313458
# Episode 5999: reward = 827.865935
# Episode 6000: reward = 826.975692
# Episode 6001: reward = 767.756203
# Episode 6002: reward = 783.831217
# Episode 6003: reward = 810.255618
# Episode 6004: reward = 833.203323
# Episode 6005: reward = 811.922916
# Episode 6006: reward = 818.797057
# Episode 6007: reward = 829.813805
# Episode 6008: reward = 795.659282
# Episode 6009: reward = 765.43674
# Episode 6010: reward = 784.885159
# Episode 6011: reward = 818.250831
# Episode 6012: reward = 824.639529
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 478          |
# |    ep_rew_mean          | 769          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 148          |
# |    time_elapsed         | 2184         |
# |    total_timesteps      | 2424832      |
# | train/                  |              |
# |    approx_kl            | 0.0021077844 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.254       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.35         |
# |    n_updates            | 1470         |
# |    policy_gradient_loss | -0.000285    |
# |    value_loss           | 37.6         |
# ------------------------------------------
# Episode 6013: reward = 817.049866
# Episode 6014: reward = 777.600249
# Episode 6015: reward = 826.133602
# Episode 6016: reward = 824.380582
# Episode 6017: reward = 824.39024
# Episode 6018: reward = 798.507648
# Episode 6019: reward = 825.573821
# Episode 6020: reward = 824.643793
# Episode 6021: reward = 19.506717
# Episode 6022: reward = 806.086018
# Episode 6023: reward = 827.846933
# Episode 6024: reward = 821.602161
# Episode 6025: reward = 788.252649
# Episode 6026: reward = 822.911827
# Episode 6027: reward = 834.592441
# Episode 6028: reward = 824.287955
# Episode 6029: reward = 833.59359
# Episode 6030: reward = 796.239426
# Episode 6031: reward = 807.026602
# Episode 6032: reward = 141.93547
# Episode 6033: reward = 831.411382
# Episode 6034: reward = 825.746043
# Episode 6035: reward = 824.709198
# Episode 6036: reward = 826.608215
# Episode 6037: reward = 823.807162
# Episode 6038: reward = 828.489913
# Episode 6039: reward = 828.974662
# Episode 6040: reward = 830.211256
# Episode 6041: reward = 790.810786
# Episode 6042: reward = 816.409852
# Episode 6043: reward = 779.747546
# Episode 6044: reward = 788.285584
# Episode 6045: reward = 822.542177
# Episode 6046: reward = 801.836097
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 482         |
# |    ep_rew_mean          | 776         |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 149         |
# |    time_elapsed         | 2199        |
# |    total_timesteps      | 2441216     |
# | train/                  |             |
# |    approx_kl            | 0.001274944 |
# |    clip_fraction        | 0.0117      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.4         |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | -0.000136   |
# |    value_loss           | 11.6        |
# -----------------------------------------
# Episode 6047: reward = 828.484343
# Episode 6048: reward = 825.332444
# Episode 6049: reward = 820.280386
# Episode 6050: reward = 835.09965
# Episode 6051: reward = 816.39779
# Episode 6052: reward = 802.050397
# Episode 6053: reward = 805.066734
# Episode 6054: reward = 18.106203
# Episode 6055: reward = 830.066532
# Episode 6056: reward = 826.31991
# Episode 6057: reward = 829.236512
# Episode 6058: reward = 828.291695
# Episode 6059: reward = 812.961889
# Episode 6060: reward = 811.834975
# Episode 6061: reward = 807.946221
# Episode 6062: reward = 804.86975
# Episode 6063: reward = 763.210242
# Episode 6064: reward = 825.410855
# Episode 6065: reward = 765.322465
# Episode 6066: reward = 752.771957
# Episode 6067: reward = 815.819767
# Episode 6068: reward = 817.116966
# Episode 6069: reward = 794.918374
# Episode 6070: reward = 813.877039
# Episode 6071: reward = 824.557705
# Episode 6072: reward = 824.18472
# Episode 6073: reward = 20.553144
# Episode 6074: reward = 814.583155
# Episode 6075: reward = 820.715327
# Episode 6076: reward = 824.990603
# Episode 6077: reward = 828.137822
# Episode 6078: reward = 17.99302
# Episode 6079: reward = 827.800728
# Episode 6080: reward = 833.224381
# Episode 6081: reward = 783.902972
# Episode 6082: reward = 816.993315
# Episode 6083: reward = 822.419568
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 480          |
# |    ep_rew_mean          | 774          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 150          |
# |    time_elapsed         | 2213         |
# |    total_timesteps      | 2457600      |
# | train/                  |              |
# |    approx_kl            | 0.0019341582 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.4         |
# |    n_updates            | 1490         |
# |    policy_gradient_loss | -0.000539    |
# |    value_loss           | 19.2         |
# ------------------------------------------
# Episode 6084: reward = 15.771474
# Episode 6085: reward = 818.132795
# Episode 6086: reward = 18.019998
# Episode 6087: reward = 828.496599
# Episode 6088: reward = 825.535857
# Episode 6089: reward = 821.981458
# Episode 6090: reward = 829.00662
# Episode 6091: reward = 808.123789
# Episode 6092: reward = 828.180744
# Episode 6093: reward = 15.540957
# Episode 6094: reward = 22.315889
# Episode 6095: reward = 786.362214
# Episode 6096: reward = 809.760783
# Episode 6097: reward = 815.162254
# Episode 6098: reward = 765.528495
# Episode 6099: reward = 828.986128
# Episode 6100: reward = 810.375103
# Episode 6101: reward = 828.127576
# Episode 6102: reward = 807.0205
# Episode 6103: reward = 805.282853
# Episode 6104: reward = 818.911069
# Episode 6105: reward = 828.286106
# Episode 6106: reward = 827.783864
# Episode 6107: reward = 785.233059
# Episode 6108: reward = 229.282864
# Episode 6109: reward = 18.226623
# Episode 6110: reward = 825.8796
# Episode 6111: reward = 803.345642
# Episode 6112: reward = 826.960249
# Episode 6113: reward = 832.480354
# Episode 6114: reward = 108.694425
# Episode 6115: reward = 782.465722
# Episode 6116: reward = 829.084788
# Episode 6117: reward = 828.345153
# Episode 6118: reward = 821.668145
# Episode 6119: reward = 820.617836
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 455          |
# |    ep_rew_mean          | 724          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 151          |
# |    time_elapsed         | 2228         |
# |    total_timesteps      | 2473984      |
# | train/                  |              |
# |    approx_kl            | 0.0022045025 |
# |    clip_fraction        | 0.00931      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | 0.971        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.5         |
# |    n_updates            | 1500         |
# |    policy_gradient_loss | -0.000325    |
# |    value_loss           | 28.7         |
# ------------------------------------------
# Episode 6120: reward = 829.773102
# Episode 6121: reward = 797.377104
# Episode 6122: reward = 18.161466
# Episode 6123: reward = 744.333261
# Episode 6124: reward = 19.490332
# Episode 6125: reward = 826.452775
# Episode 6126: reward = 803.693103
# Episode 6127: reward = 831.448458
# Episode 6128: reward = 17.537987
# Episode 6129: reward = 825.414603
# Episode 6130: reward = 759.736821
# Episode 6131: reward = 823.035242
# Episode 6132: reward = 779.38315
# Episode 6133: reward = 750.029028
# Episode 6134: reward = 812.255994
# Episode 6135: reward = 787.779331
# Episode 6136: reward = 825.793884
# Episode 6137: reward = 789.338363
# Episode 6138: reward = 20.829326
# Episode 6139: reward = 824.90922
# Episode 6140: reward = 826.789088
# Episode 6141: reward = 816.415606
# Episode 6142: reward = 794.180291
# Episode 6143: reward = 827.633368
# Episode 6144: reward = 833.568954
# Episode 6145: reward = 833.572533
# Episode 6146: reward = 817.909642
# Episode 6147: reward = 835.290446
# Episode 6148: reward = 834.205896
# Episode 6149: reward = 825.697475
# Episode 6150: reward = 824.275604
# Episode 6151: reward = 19.062917
# Episode 6152: reward = 802.480051
# Episode 6153: reward = 127.531083
# Episode 6154: reward = 15.405618
# Episode 6155: reward = 161.576726
# Episode 6156: reward = 822.045486
# Episode 6157: reward = 835.011328
# Episode 6158: reward = 816.749592
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 435          |
# |    ep_rew_mean          | 683          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 152          |
# |    time_elapsed         | 2242         |
# |    total_timesteps      | 2490368      |
# | train/                  |              |
# |    approx_kl            | 0.0029156697 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.954        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.1         |
# |    n_updates            | 1510         |
# |    policy_gradient_loss | -0.000408    |
# |    value_loss           | 58.1         |
# ------------------------------------------
# Episode 6159: reward = 831.930296
# Episode 6160: reward = 829.442173
# Episode 6161: reward = 821.87521
# Episode 6162: reward = 825.508144
# Episode 6163: reward = 826.774529
# Episode 6164: reward = 816.76347
# Episode 6165: reward = 818.045872
# Episode 6166: reward = 807.39839
# Episode 6167: reward = 839.258354
# Episode 6168: reward = 838.527392
# Episode 6169: reward = 832.167788
# Episode 6170: reward = 794.641804
# Episode 6171: reward = 826.964767
# Episode 6172: reward = 823.486589
# Episode 6173: reward = 828.846237
# Episode 6174: reward = 809.055881
# Episode 6175: reward = 794.366857
# Episode 6176: reward = 815.917999
# Episode 6177: reward = 827.268461
# Episode 6178: reward = 16.543486
# Episode 6179: reward = 835.636355
# Episode 6180: reward = 811.835029
# Episode 6181: reward = 827.710167
# Episode 6182: reward = 16.906383
# Episode 6183: reward = 825.201287
# Episode 6184: reward = 830.517406
# Episode 6185: reward = 14.005172
# Episode 6186: reward = 831.773997
# Episode 6187: reward = 835.232329
# Episode 6188: reward = 804.702505
# Episode 6189: reward = 824.707839
# Episode 6190: reward = 836.240179
# Episode 6191: reward = 85.760877
# Episode 6192: reward = 818.821648
# Episode 6193: reward = 820.641286
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | 695          |
# | time/                   |              |
# |    fps                  | 1110         |
# |    iterations           | 153          |
# |    time_elapsed         | 2257         |
# |    total_timesteps      | 2506752      |
# | train/                  |              |
# |    approx_kl            | 0.0021659115 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.35         |
# |    n_updates            | 1520         |
# |    policy_gradient_loss | -0.000451    |
# |    value_loss           | 57.9         |
# ------------------------------------------
# Training finished.

# %%
# !pip install statsmodels --quiet
import statsmodels.api as sm

rewards = callback.all_rewards
lowess = sm.nonparametric.lowess
smoothed = lowess(rewards, np.arange(len(rewards)), frac=0.05)  # frac controls smoothing

plt.figure(figsize=(10,5))
plt.plot(rewards, '.', alpha=0.3, label='Raw reward')
plt.plot(smoothed[:,0], smoothed[:,1], 'r-', linewidth=2, label='LOWESS smooth')
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("LOWESS Smoothed Reward Curve")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
model.save("ppo_cartpole_swingup_checkpoint")
print("✅ 模型已成功保存到google drive")
# Out:
# ✅ 模型已成功保存到google drive
